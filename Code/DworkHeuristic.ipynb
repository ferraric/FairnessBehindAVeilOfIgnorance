# %% [markdown]
# # Here we try to implement Fairness through Awareness by Dwork et. al.

# %% [markdown]
# ## Since the original formulation has $O(n^2)$ constraints we try a heuristic approach

# %% [markdown]
# Import necessary dependencies.
# Note that the modules "utils_modified" and "funcs_disp_mist_modified" containing some helper functions are adopted from "Fairness Beyond Disparate Treatment & Disparate Impact: Learning Classification without Disparate Mistreatment" by Zafar et. al. (https://github.com/mbilalzafar/fair-classification)

# %%
import scipy.io
import sys
import numpy as np
import compas_preprocessing as preproc
import funcs_disp_mist_modified as fdm
from helpers import *
from random import shuffle
from cvxpy import *
from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit

# %% [markdown]
# ## Importing the COMPAS dataset

# %% [markdown]
# Here we import the COMPAS dataset. It is preprocessed the same way as in the ProPublica study (refer to https://github.com/propublica/compas-analysis)

# %%
X, y, x_control = preproc.load_compas_data_modified()
sensitive_attrs = list(x_control.keys())

# since we want +1 to be the desired outcome we have to flip our training labels
# previously +1 indicated that a person recidivated within 2 years
y = -y
# Out:
# Looking for file 'compas-scores-two-years.csv' in the current directory...
# File found in current directory..
#
# Number of people recidivating within two years
# -1    2795
#  1    2483
# dtype: int64
#
#
# Features we will be using for classification are: ['intercept', 'age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'race', 'sex', 'priors_count', 'c_charge_degree']

# %% [markdown]
# Here we compute the maximum distance between any two data points in order to be able to compute the normalized distance

# %%
n = X.shape[0]
D = np.zeros((n,n))
for i in range(n):
    for j in range(n):
        D[i,j] = np.linalg.norm(X[i,:]- X[j,:])
d_max = D.max()

# %% [markdown]
# Setting some parameters for the solver

# %%
max_iters = 100 # for the convex program
max_iter_dccp = 50  # for the dccp algo
tau, mu = 0.005, 1.2 # default dccp parameters, need to be varied per dataset

# %% [markdown]
# ## Approach

# %% [markdown]
# We will first train an unconstrained classifier on the training set and evaluate which constraints are violated by more than delta. A priori we determine how many constraints we can enforce with reasonable computational effort (max_num_cons). Then we choose delta as large as possible such that we still have more violations that we can enforce. That is done in an approximate fashion because it stays the same across all train/test splits.
# We generate a list of all those violations. Then we iterate over and enforce x constraints where 0<=x<=max_num_cons. We evaluate on the validation set how many constraints are still violated and the average violation of the constraints.

# %% [markdown]
# ### Generate cross validation splits for both training and evaulation

# %%
cross_val_iter = 10
kf = KFold(n_splits=cross_val_iter,shuffle=True)

# %% [markdown]
# ## Here we train our classifier with different alpha and tau values and save the resulting weight vectors

# %% [markdown]
# Note that you need to run this part first before running the evaluation part. Also if the solver fails in one cross validation iteration the value of the weight vector is discarded. However, the computation for that only works after the first cross validation iteration. So if the solver does fail in the first iteration, you get a corresponding error message and need to rerun the training part.

# %%
max_num_cons = 9000
iterations = 20
delta = 0.55
num_cons_array = np.linspace(0,max_num_cons,iterations)

# number of features in the dataset
no_features = X.shape[1]

# Here we will put the weights resulting from the training of the classifier
weight_matrix = np.zeros((iterations,no_features))

i = 0
for train_index, test_index in kf.split(X):
    print("#############cross validation iteration " + str(i) + " #########################")
    x_train, x_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    x_control_train = {'race':x_control['race'][train_index]}
    x_control_test = {'race':x_control['race'][test_index]}
    num_points, num_features = x_train.shape
    
    # initialize weight vectors to a random value
    w_uncons = Variable(num_features)
    w_uncons.value = np.random.rand(num_features)
    # logistic loss
    loss = sum_entries(logistic( mul_elemwise(-y_train, x_train*w_uncons) )  ) / num_points # we are converting y to a diagonal matrix for consistent

    prob = Problem(Minimize(loss),[norm(w_uncons) == 1])

    try:
        prob.solve(method='dccp', tau=tau, mu=mu, tau_max=1e10,
                solver=ECOS, verbose=False,
                max_iters=max_iters, max_iter=max_iter_dccp)
    except Exception as e:
        print (e)

    #convert solution vector to a numpy array
    w_uncons = np.array(w_uncons.value).flatten()
    
    # list of all constraints that are violated by an unconstrained classifier
    vio_list_uncons = violated_pairs(np.reciprocal(1+np.exp(-np.dot(x_train, w_uncons))), x_train, delta, d_max)
    print("we could enforce up to this many violations:")
    print(len(vio_list_uncons))
    
    shuffle(vio_list_uncons)
    for k in range(iterations):
        print("================= iteration: " + str(k) + " ====================")

        # initialize weight vectors to a random value
        w_cons = Variable(num_features)
        w_cons.value = np.random.rand(x_train.shape[1])

        # logistic loss
        loss = sum_entries(logistic( mul_elemwise(-y_train, x_train*w_cons) )  ) / num_points # we are converting y to a diagonal matrix for consistent

        #scale the predictions to be in [-1,1]
        y_pred = (x_train*w_cons)/5

        constraints = [norm(w_cons) == 1]

        num_cons = int(num_cons_array[k])
        
        # now we add the obtained constraints to our optimization problem
        for (i1,j1) in vio_list_uncons[:num_cons]:
            constraints.append(abs(y_pred[i1] - y_pred[j1]) <= distance(x_train[i1,:],x_train[j1,:], d_max))


        prob = Problem(Minimize(loss),constraints)

        solver_failed = False
        
        try:
            prob.solve(method='dccp', tau=tau, mu=mu, tau_max=1e10,
                    solver=ECOS, verbose=False,
                    max_iters=max_iters, max_iter=max_iter_dccp)
        except Exception as e:
            print (e)
            solver_failed = True
            
        if prob.status != "Converged" and prob.status != "OPTIMAL":
                solver_failed = True

        if not solver_failed: 
            w_cons = np.array(w_cons.value).flatten()
            
            print(w_cons)
            
            weight_matrix[k,:] += w_cons/cross_val_iter
            
            train_score, test_score, cov_all_train, cov_all_test, s_attr_to_fp_fn_train, s_attr_to_fp_fn_test = fdm.get_clf_stats(w_cons, x_train, y_train, x_control_train, x_test, y_test, x_control_test, sensitive_attrs)
        else:
            # test if all values 0, which they are only in the first cross validation iteration
            if not np.any(weight_matrix[k,:]):
                sys.exit("Solver failed in first cross validation iteration")
            else:
                weight_matrix[k,:] = weight_matrix[k,:]*(i + 1)/i

        print(prob.status)
    i += 1
# Out:
# #############cross validation iteration 0 #########################
# we could enforce up to this many violations:
# 102578
# ================= iteration: 0 ====================
# [ 0.20900779  0.50918733 -0.0252926   0.00976185 -0.12842913  0.06675674
#  -0.25524398 -0.75651861  0.19464992]
# [ 1. -1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.642
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.37 || 0.35 ||
# ||  1  || 0.62 || 0.19 ||
#
#
# Converged
# ================= iteration: 1 ====================
# [ 0.14532862  0.07531194 -0.03595068 -0.04321315 -0.0472088   0.01116118
#  -0.03803255 -0.10922222  0.02559014]
# [ 1.  1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.10 ||
# ||  1  || 0.87 || 0.06 ||
#
#
# Converged
# ================= iteration: 2 ====================
# [ 0.13228576  0.08774723 -0.03929965 -0.03441464 -0.04268266  0.01447607
#  -0.02949419 -0.09971054  0.03499608]
# [ 1.  1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.12 ||
# ||  1  || 0.87 || 0.06 ||
#
#
# Converged
# ================= iteration: 3 ====================
# [ 0

# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.88 || 0.02 ||
#
#
# Converged
# ================= iteration: 17 ====================
# [ 0.1347581   0.07957899 -0.03981524 -0.02702331 -0.03897723  0.01489846
#  -0.02279128 -0.11000311  0.01267902]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.88 || 0.02 ||
#
#
# Converged
# ================= iteration: 18 ====================
# [ 0.13496645  0.07957899 -0.03981524 -0.02702331 -0.03897723  0.01489846
#  -0.02279128 -0.11000311  0.01267902]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.88 || 0.02 ||
#
#
# Converged
# ================= iteration: 19 ====================
# [ 0.13492885  0.07957899 -0.03981524 -0.02702331 -0.03897723  0.01489846
#  -0.02279128 -0.11000311  0.01267902]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.88 || 0.02 ||
#
#
# Converged
# #############cross validation iteration 9 #########################
# we could enforce up to this many violations:
# 85631
# ================= iteration: 0 ====================
# [ 0.26294189  0.4913379  -0.03808218  0.03254386 -0.13808371  0.06627776
#  -0.29826109 -0.7366617   0.17846369]
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.702
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.29 || 0.30 ||
# ||  1  || 0.59 || 0.12 ||
#
#
# Converged
# ================= iteration: 1 ====================
# [ 0.13715117  0.08055993 -0.0424576  -0.03043806 -0.03787527  0.00853966
#  -0.01982602 -0.10865117  0.04262574]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.615
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.86 || 0.04 ||
#
#
# Converged
# ================= iteration: 2 ====================
# [ 0.1558979   0.08102797 -0.03965363 -0.03128512 -0.03397979  0.01967951
#  -0.03899091 -0.10732596  0.02254808]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.87 || 0.04 ||
#
#
# Converged
# ================= iteration: 3 ====================
# [ 0.14627812  0.08358625 -0.04126419 -0.02608851 -0.03251154  0.01590559
#  -0.02618356 -0.10909956  0.02414893]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.620
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.84 || 0.03 ||
#
#
# Converged
# ================= iteration: 4 ====================
# [ 0.14065953  0.08053781 -0.04179446 -0.02435102 -0.03498097  0.02071995
#  -0.0228055  -0.10985353  0.02518201]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.87 || 0.04 ||
#
#
# Converged
# ================= iteration: 5 ====================
# [ 0.14400075  0.08098167 -0.03974265 -0.02418149 -0.03502353  0.0152781
#  -0.02337453 -0.11074507  0.02598132]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 6 ====================
# [ 0.14674507  0.07971253 -0.03856311 -0.02392182 -0.03420791  0.0171597
#  -0.02668662 -0.11170576  0.02235627]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 7 ====================
# [ 0.1471963   0.07971253 -0.03856311 -0.02392182 -0.03420791  0.0171597
#  -0.02668662 -0.11170576  0.02235627]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 8 ====================
# [ 0.14774367  0.07929547 -0.03884018 -0.02391814 -0.034016    0.01927852
#  -0.02749718 -0.11163643  0.021048  ]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.86 || 0.03 ||
#
#
# Converged
# ================= iteration: 9 ====================
# Combined backtracking failed 0 0 90 0 sigma 1
# Solver 'ECOS' failed. Try another solver.
# None
# ================= iteration: 10 ====================
# [ 0.14685108  0.07709259 -0.0401414  -0.02622385 -0.03516994  0.02056541
#  -0.0269251  -0.11146311  0.01918904]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.615
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.86 || 0.03 ||
#
#
# Converged
# ================= iteration: 11 ====================
# [ 0.14600129  0.07766028 -0.03884062 -0.02630263 -0.03745998  0.01282718
#  -0.02344928 -0.11166388  0.02345145]
# [1. 1. 1. ... 1. 1. 1.]
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 12 ====================
# [ 0.14611018  0.07693394 -0.03884425 -0.02613206 -0.03706652  0.0144962
#  -0.02411795 -0.11206492  0.0224511 ]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 13 ====================
# [ 0.14568085  0.07950917 -0.03857017 -0.02684625 -0.0407464   0.00849548
#  -0.02166563 -0.10961091  0.02502087]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 14 ====================
# [ 0.14559472  0.07950916 -0.03857017 -0.02684625 -0.0407464   0.00849548
#  -0.02166563 -0.10961091  0.02502087]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 15 ====================
# [ 0.14598233  0.07952226 -0.0385272  -0.02684773 -0.04070237  0.00850377
#  -0.02180577 -0.10961868  0.0249021 ]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 16 ====================
# [ 0.14585289  0.07952226 -0.0385272  -0.02684773 -0.04070237  0.00850377
#  -0.02180577 -0.10961868  0.0249021 ]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 17 ====================
# [ 0.14587485  0.07952226 -0.0385272  -0.02684773 -0.04070237  0.00850377
#  -0.02180577 -0.10961868  0.0249021 ]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 18 ====================
# [ 0.14548478  0.07908547 -0.03869148 -0.02711816 -0.04068005  0.00833032
#  -0.02135898 -0.10986219  0.02515183]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged
# ================= iteration: 19 ====================
# [ 0.14545945  0.07908547 -0.03869148 -0.02711816 -0.04068005  0.00833032
#  -0.02135898 -0.10986219  0.02515183]
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# Converged

# %% [markdown]
# ### Saving the obtained weight vectors

# %%
scipy.io.savemat("../Result_Data/DworkHeuristic/W_matrix_heuristic",{'dummykey':weight_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/no_constraints_heuristic",{'dummykey':num_cons_array})

# %% [markdown]
# ## Here we evaluate different metrics for all the weight vectors we got from the training process above

# %% [markdown]
# Note that we have to use the same validation splits to ensure testing is really done on validation data and not on data already seen during training.

# %%
# for computing atkinson's index and social welfare
alpha = 0.8

delta_array = [0]
num_vio_array1 = np.zeros((iterations,len(delta_array)))
num_vio_array2 = np.zeros((iterations,len(delta_array)))
num_vio_array3 = np.zeros((iterations,len(delta_array)))

avg_vio_array1 = np.zeros(iterations)
avg_vio_array2 = np.zeros(iterations)
avg_vio_array3 = np.zeros(iterations)

#false positive rate
fpr_matrix = np.zeros(iterations)
# false negative rate
fnr_matrix = np.zeros(iterations)
# holds the absolute difference in percentage of positive outcomes
dp_matrix = np.zeros(iterations)
# holds the atkinsons index
at_matrix = np.zeros(iterations)
# holds ge2 unfairness
ge_matrix = np.zeros(iterations)
# holds accuracy
accuracy_matrix = np.zeros(iterations)
# holds social welfare
welfare_matrix = np.zeros(iterations)


i = 0
for train_index, test_index in kf.split(X):
    print("#############cross validation iteration " + str(i) + " #########################")
    x_train, x_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    x_control_train = {'race':x_control['race'][train_index]}
    x_control_test = {'race':x_control['race'][test_index]}
    num_points, num_features = x_train.shape

    
    shuffle(vio_list_uncons)
    for k in range(iterations):
        print("================= iteration: " + str(k) + " ====================")
        
        w_cons = weight_matrix[k,:]
        
        
        train_score, test_score, cov_all_train, cov_all_test, s_attr_to_fp_fn_train, s_attr_to_fp_fn_test = fdm.get_clf_stats(w_cons, x_train, y_train, x_control_train, x_test, y_test, x_control_test, sensitive_attrs)
        y_pred_test = np.sign(np.dot(x_test, w_cons))
        y_pred_test2 = np.reciprocal(1+np.exp(-np.dot(x_test, w_cons)))
        y_pred_test3 = (np.dot(x_test, w_cons))/5
        

        group_array = x_control_test['race']

        # total number of positive and negative points
        unique, counts = np.unique(y_test, return_counts=True)
        n_neg1 = 0
        n_pos1 = 0

        n_neg0 = 0
        n_pos0 = 0


        # total number of data points
        n = y_test.shape[0]
        unique, counts = np.unique(group_array, return_counts=True)
        # number of people in group 0
        n0 = counts[0]
        # number of people in group 1
        n1 = counts[1]

        # positive prediction count for both classes and for predicted labels
        pos_count0_pred = 0
        pos_count1_pred = 0
        fp_count0 = 0
        fp_count1 = 0
        fn_count0 = 0
        fn_count1 = 0

        counter = 0
        for group_membership in group_array:
            if group_membership == 1:
                if y_test[counter] == 1:
                    n_pos1 += 1
                if y_test[counter] == -1:
                    n_neg1 += 1
                # demographic parity check
                if y_pred_test[counter] == 1:
                    pos_count1_pred += 1
                #fpr fnr check
                if y_test[counter] == 1 and y_pred_test[counter] == -1:
                    fn_count1 += 1
                if y_test[counter] == -1 and y_pred_test[counter] == 1:
                    fp_count1 += 1
            elif group_membership == 0:
                if y_test[counter] == 1:
                    n_pos0 += 1
                if y_test[counter] == -1:
                    n_neg0 += 1
                # demographic parity check
                if y_pred_test[counter] == 1:
                    pos_count0_pred += 1
                #fpr fnr check
                if y_test[counter] == 1 and y_pred_test[counter] == -1:
                    fn_count0 += 1
                if y_test[counter] == -1 and y_pred_test[counter] == 1:
                    fp_count0 += 1
            else:
                print("ERROR")
            counter += 1
        
        ge_matrix[k] += ge2(y_pred_test, y_test) / cross_val_iter
        accuracy_matrix[k] += test_score / cross_val_iter
        fpr_matrix[k] += (fp_count0/n_neg0 - fp_count1/n_neg1) / cross_val_iter
        fnr_matrix[k] += (fn_count0/n_pos0 - fn_count1/n_pos1) / cross_val_iter
        dp_matrix[k] += (pos_count0_pred/n0 - pos_count1_pred/n1) / cross_val_iter
        at_matrix[k] += atk(y_pred_test, y_test, alpha) / cross_val_iter
        welfare_matrix[k] += eval_util(y_pred_test, y_test, alpha)/ cross_val_iter


        
        print("evaluating avg violation")
        avg_vio_array1[k] += avg_Dwork_violation(y_pred_test, x_test, 0, d_max)/cross_val_iter
        avg_vio_array2[k] += avg_Dwork_violation(y_pred_test2, x_test, 0, d_max)/cross_val_iter
        avg_vio_array3[k] += avg_Dwork_violation(y_pred_test3, x_test, 0, d_max)/cross_val_iter
        for j in range(len(delta_array)):
            print("evaluating no violation")
            d = delta_array[j]
            num_vio_array1[k][j] += num_Dwork_violation(y_pred_test, x_test, d, d_max)/cross_val_iter
            num_vio_array2[k][j] += num_Dwork_violation(y_pred_test2, x_test, d, d_max)/cross_val_iter
            num_vio_array3[k][j] += num_Dwork_violation(y_pred_test3, x_test, d, d_max)/cross_val_iter
    
    i += 1
dp_matrix = np.absolute(dp_matrix)
fpr_matrix = np.absolute(fpr_matrix)
fnr_matrix = np.absolute(fnr_matrix)
# Out:
# #############cross validation iteration 0 #########################
# ================= iteration: 0 ====================
# [-1.  1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.686
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.27 || 0.34 ||
# ||  1  || 0.68 || 0.10 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.623
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.12 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.623
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.62 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.64 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.64 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.63 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.64 || 0.13 ||
# ||  1  || 0.84 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 1 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.708
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.28 || 0.32 ||
# ||  1  || 0.57 || 0.11 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.623
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.11 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.627
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.10 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
# Accuracy: 0.631
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.629
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.89 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 2 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.648
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.33 || 0.35 ||
# ||  1  || 0.66 || 0.15 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.608
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.72 || 0.09 ||
# ||  1  || 0.87 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.610
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.87 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.610
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.87 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.610
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.87 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.614
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.09 ||
# ||  1  || 0.85 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 3 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.697
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.32 || 0.28 ||
# ||  1  || 0.64 || 0.15 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.640
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.06 ||
# ||  1  || 0.89 || 0.07 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.634
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.07 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.634
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.07 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.638
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.06 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.06 ||
# ||  1  || 0.89 || 0.07 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.636
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.06 ||
# ||  1  || 0.89 || 0.07 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.638
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.06 ||
# ||  1  || 0.89 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 4 #########################
# ================= iteration: 0 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.684
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.27 || 0.29 ||
# ||  1  || 0.72 || 0.13 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.585
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.02 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.587
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.02 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.95 || 0.02 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.595
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.07 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.593
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.96 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.02 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.95 || 0.01 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 5 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.669
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.29 || 0.34 ||
# ||  1  || 0.62 || 0.16 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.587
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.08 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.587
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.08 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.08 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.587
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.08 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.591
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.587
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.589
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.69 || 0.07 ||
# ||  1  || 0.91 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 6 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.663
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.30 || 0.41 ||
# ||  1  || 0.58 || 0.11 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.07 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.68 || 0.06 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 7 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.686
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.31 || 0.33 ||
# ||  1  || 0.57 || 0.15 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.621
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.619
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.617
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.616
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.09 ||
# ||  1  || 0.84 || 0.06 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 8 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ... -1.  1.  1.]
#
#
# Accuracy: 0.651
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.36 || 0.34 ||
# ||  1  || 0.68 || 0.15 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.609
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.613
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.70 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.609
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.611
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.609
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.71 || 0.08 ||
# ||  1  || 0.90 || 0.03 ||
#
#
# evaluating avg violation
# evaluating no violation
# #############cross validation iteration 9 #########################
# ================= iteration: 0 ====================
# [ 1. -1.  1. ...  1.  1.  1.]
#
#
# Accuracy: 0.700
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.30 || 0.32 ||
# ||  1  || 0.53 || 0.14 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 1 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.645
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.65 || 0.09 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 2 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.65 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 3 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.65 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 4 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.65 || 0.08 ||
# ||  1  || 0.81 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 5 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 6 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 7 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 8 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 9 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.643
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.66 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 10 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.645
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.65 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 11 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 12 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 13 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 14 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 15 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 16 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 17 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 18 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation
# ================= iteration: 19 ====================
# [1. 1. 1. ... 1. 1. 1.]
#
#
# Accuracy: 0.641
# ||  s  || FPR. || FNR. ||
# ||  0  || 0.67 || 0.08 ||
# ||  1  || 0.80 || 0.04 ||
#
#
# evaluating avg violation
# evaluating no violation

# %% [markdown]
# ### Saving the obtained results

# %%
dwork_avg = np.column_stack((avg_vio_array1,avg_vio_array2,avg_vio_array3))
dwork_no = np.column_stack((num_vio_array1[:,0],num_vio_array2[:,0],num_vio_array3[:,0]))

scipy.io.savemat("../Result_Data/DworkHeuristic/dwork_avg_matrix_heuristic",{'dummykey':dwork_avg})
scipy.io.savemat("../Result_Data/DworkHeuristic/dwork_no_matrix_heuristic",{'dummykey':dwork_no})
scipy.io.savemat("../Result_Data/DworkHeuristic/fpr_matrix_heuristic",{'dummykey':fpr_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/fnr_matrix_heuristic",{'dummykey':fnr_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/dp_matrix_heuristic",{'dummykey':dp_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/ge_matrix_heuristic",{'dummykey':ge_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/accuracy_matrix_heuristic",{'dummykey':accuracy_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/at_matrix_heuristic",{'dummykey':at_matrix})
scipy.io.savemat("../Result_Data/DworkHeuristic/welfare_matrix_heuristic",{'dummykey':welfare_matrix})
